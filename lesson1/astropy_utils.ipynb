# %% [markdown]
# # Using Astropy
#
# ## Coordinate conversion
#
# Astropy provides useful tools to convert between the coordinate systems.
#
# The International Celestial Reference System (ICRS) is the current standard celestial reference system adopted by the International Astronomical Union (IAU).
# Its origin is at the barycenter of the Solar System, with axes that are intended to "show no global rotation with respect to a set of distant extragalactic objects".

# %%
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wget in /usr/local/lib/python3.9/dist-packages (3.2)

# %%
import astropy 
import pylab as pl 
from astropy import units as u
from astropy import constants as const 
from astropy.coordinates import SkyCoord
import wget
import numpy as np

# %%
coord1 = SkyCoord(ra=10.625*u.degree, dec=41.2*u.degree, frame='icrs')

# %% [markdown]
# sometimes however RA is referred in _hourangle_ units and Declination in degrees, minutes and seconds

# %%
coord2 = SkyCoord('00h42m30s', '+41d12m00s', frame='icrs')

# %% [markdown]
# we can then use the conversion tool to switch between one unit frame and the other , as well as different coordinate system

# %%
print(coord1.ra.to((u.hourangle)),
coord2.dec.to(u.deg) ,
coord1.galactic,   )
# Out:
# 0h42m30s 41d12m00s <SkyCoord (Galactic): (l, b) in deg
#     (121.12334339, -21.6403587)>

# %% [markdown]
# It is also possible to input coordinate values in other representations
# such as cartesian or cylindrical.  In this case one includes the keyword
# argument ``representation_type='cartesian'`` (for example) along with data
# in ``x``, ``y``, and ``z`` , we need to provide a distance though. this is very useful when dealing with 3D volume data.

# %%
coord3 = SkyCoord(0*u.deg, 0*u.deg,'100kpc', frame='galactic')
print(coord3, coord3.cartesian, coord3.cylindrical, coord3.spherical)
# Out:
# <SkyCoord (Galactic): (l, b, distance) in (deg, deg, kpc)
#     (0., 0., 100.)> (100., 0., 0.) kpc (100., 0., 0.) (kpc, deg, kpc) (0., 0., 100.) (deg, deg, kpc)

# %% [markdown]
# ## using constants and units

# %%
Tsun= 5000 *u.K 
print((const.k_B*Tsun).to(u.eV)) 
wavelength= 800 *u.um 
freq= (const.c/wavelength).to(u.THz)
print(freq)
# Out:
# 0.4308666631072589 eV
# 0.3747405725 THz

# %% [markdown]
# ## reading   data FITS format
# Flexible Image Transport System (FITS) is an open standard defining a digital file format useful for storage, transmission and processing of data: formatted as multi-dimensional arrays (for example a 2D image), or tables. FITS is the most commonly used digital file format in astronomy. The FITS standard was designed specifically for astronomical data, and includes provisions such as describing photometric and spatial calibration information, together with image origin metadata.
#
# The FITS format was first standardized in 1981; it has evolved gradually since then, and the most recent version (4.0) was standardized in 2016. FITS was designed with an eye towards long-term archival storage, and the maxim once FITS, always FITS represents the requirement that developments to the format must be backward compatible.
#
# Image metadata is stored in a human-readable ASCII header. The information in this header is designed to calculate the byte offset of some information in the subsequent data unit to support direct access to the data cells. Each FITS file consists of one or more headers containing ASCII card images that carry keyword/value pairs, interleaved between data blocks. The keyword/value pairs provide information such as size, origin, coordinates, binary data format, free-form comments, history of the data, and anything else the creator desires: while many keywords are reserved for FITS use, the standard allows arbitrary use of the rest of the name-space.
#
# FITS is also often used to store non-image data, such as spectra, photon lists, data cubes, or structured data such as multi-table databases. A FITS file may contain several extensions, and each of these may contain a data object. For example, it is possible to store x-ray and infrared exposures in the same file.
#
# #### Download the Data Release 1 of Gaia
#
# we download  data from the 1st GAIA data release, these data encode parallaxes of tons of stars.

# %%
from astropy.io import fits ,ascii 
try : 
    hdu = fits.open( 'GaiaSource_000-000-000.fits')
except FileNotFoundError:
    file = wget.download("http://cdn.gea.esac.esa.int/Gaia/gdr1/gaia_source/fits/GaiaSource_000-000-000.fits") 
    hdu = fits.open( 'GaiaSource_000-000-000.fits')

# %% [markdown]
# ### FITS  headers
# Every Header Data Unit (HDU) normally has two components: header and data. In astropy these two components are accessed through the two attributes of the HDU, hdu.header and hdu.data.
#
# While an HDU may have empty data (i.e., the .data attribute is None), any HDU will always have a header.
#
# Usually the primary header looks like this :

# %%
hdu[0].header,
# Out:
# (SIMPLE  =                    T / Standard FITS format
#  BITPIX  =                    8 / Character data
#  NAXIS   =                    1 / Text string
#  NAXIS1  =                36532 / Number of characters
#  VOTMETA =                    T / Table metadata in VOTable format
#  EXTEND  =                    T / There are standard extensions
#  COMMENT
#  COMMENT The data in this primary HDU consists of bytes which
#  COMMENT comprise a VOTABLE document.
#  COMMENT The VOTable describes the metadata of the table contained
#  COMMENT in the following BINTABLE extension.
#  COMMENT Such a BINTABLE extension can be used on its own as a perfectly
#  COMMENT good table, but the information from this HDU may provide some
#  COMMENT useful additional metadata.
#  COMMENT There is one following BINTABLE.
#  NTABLE  =                    1 / Number of following BINTABLE HDUs              ,)

# %% [markdown]
# the second header is the card encoding the astrophysical infos, the format of each columns,the units, the name ,etc...

# %%
hdu[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional table
# NAXIS1  =                  321 / width of table in bytes
# NAXIS2  =               218453 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group
# TFIELDS =                   57 / number of columns
# EXTNAME = 'GaiaSource_000-000-000.fits' / table name
# TTYPE1  = 'solution_id'        / label for column 1
# TFORM1  = 'K       '           / format for column 1
# TUCD1   = 'meta.id;meta.version'
# TTYPE2  = 'source_id'          / label for column 2
# TFORM2  = 'K       '           / format for column 2
# TUCD2   = 'meta.id;meta.main'
# TTYPE3  = 'random_index'       / label for column 3
# TFORM3  = 'K       '           / format for column 3
# TUCD3   = 'meta.code'
# TTYPE4  = 'ref_epoch'          / label for column 4
# TFORM4  = 'D       '           / format for column 4
# TUNIT4  = 'Time[Julian Years]' / units for column 4
# TUCD4   = 'meta.ref;time.epoch'
# TTYPE5  = 'ra      '           / label for column 5
# TFORM5  = 'D       '           / format for column 5
# TUNIT5  = 'Angle[deg]'         / units for column 5
# TUCD5   = 'pos.eq.ra;meta.main'
# TTYPE6  = 'ra_error'           / label for column 6
# TFORM6  = 'D       '           / format for column 6
# TUNIT6  = 'Angle[mas]'         / units for column 6
# TUCD6   = 'stat.error;pos.eq.ra'
# TTYPE7  = 'dec     '           / label for column 7
# TFORM7  = 'D       '           / format for column 7
# TUNIT7  = 'Angle[deg]'         / units for column 7
# TUCD7   = 'pos.eq.dec;meta.main'
# TTYPE8  = 'dec_error'          / label for column 8
# TFORM8  = 'D       '           / format for column 8
# TUNIT8  = 'Angle[mas]'         / units for column 8
# TUCD8   = 'stat.error;pos.eq.dec'
# TTYPE9  = 'parallax'           / label for column 9
# TFORM9  = 'D       '           / format for column 9
# TUNIT9  = 'Angle[mas]'         / units for column 9
# TUCD9   = 'pos.parallax'
# TTYPE10 = 'parallax_error'     / label for column 10
# TFORM10 = 'D       '           / format for column 10
# TUNIT10 = 'Angle[mas]'         / units for column 10
# TUCD10  = 'stat.error;pos.parallax'
# TTYPE11 = 'pmra    '           / label for column 11
# TFORM11 = 'D       '           / format for column 11
# TUNIT11 = 'Angular Velocity[mas/year]' / units for column 11
# TUCD11  = 'pos.pm;pos.eq.ra'
# TTYPE12 = 'pmra_error'         / label for column 12
# TFORM12 = 'D       '           / format for column 12
# TUNIT12 = 'Angular Velocity[mas/year]' / units for column 12
# TUCD12  = 'stat.error;pos.pm;pos.eq.ra'
# TTYPE13 = 'pmdec   '           / label for column 13
# TFORM13 = 'D       '           / format for column 13
# TUNIT13 = 'Angular Velocity[mas/year]' / units for column 13
# TUCD13  = 'pos.pm;pos.eq.dec'
# TTYPE14 = 'pmdec_error'        / label for column 14
# TFORM14 = 'D       '           / format for column 14
# TUNIT14 = 'Angular Velocity[mas/year]' / units for column 14
# TUCD14  = 'stat.error;pos.pm;pos.eq.dec'
# TTYPE15 = 'ra_dec_corr'        / label for column 15
# TFORM15 = 'E       '           / format for column 15
# TUNIT15 = 'Dimensionless[see description]' / units for column 15
# TUCD15  = 'stat.correlation'
# TTYPE16 = 'ra_parallax_corr'   / label for column 16
# TFORM16 = 'E       '           / format for column 16
# TUNIT16 = 'Dimensionless[see description]' / units for column 16
# TUCD16  = 'stat.correlation'
# TTYPE17 = 'ra_pmra_corr'       / label for column 17
# TFORM17 = 'E       '           / format for column 17
# TUNIT17 = 'Dimensionless[see description]' / units for column 17
# TUCD17  = 'stat.correlation'
# TTYPE18 = 'ra_pmdec_corr'      / label for column 18
# TFORM18 = 'E       '           / format for column 18
# TUNIT18 = 'Dimensionless[see description]' / units for column 18
# TUCD18  = 'stat.correlation'
# TTYPE19 = 'dec_parallax_corr'  / label for column 19
# TFORM19 = 'E       '           / format for column 19
# TUNIT19 = 'Dimensionless[see description]' / units for column 19
# TUCD19  = 'stat.correlation'
# TTYPE20 = 'dec_pmra_corr'      / label for column 20
# TFORM20 = 'E       '           / format for column 20
# TUNIT20 = 'Dimensionless[see description]' / units for column 20
# TUCD20  = 'stat.correlation'
# TTYPE21 = 'dec_pmdec_corr'     / label for column 21
# TFORM21 = 'E       '           / format for column 21
# TUNIT21 = 'Dimensionless[see description]' / units for column 21
# TUCD21  = 'stat.correlation'
# TTYPE22 = 'parallax_pmra_corr' / label for column 22
# TFORM22 = 'E       '           / format for column 22
# TUNIT22 = 'Dimensionless[see description]' / units for column 22
# TUCD22  = 'stat.correlation'
# TTYPE23 = 'parallax_pmdec_corr' / label for column 23
# TFORM23 = 'E       '           / format for column 23
# TUNIT23 = 'Dimensionless[see description]' / units for column 23
# TUCD23  = 'stat.correlation'
# TTYPE24 = 'pmra_pmdec_corr'    / label for column 24
# TFORM24 = 'E       '           / format for column 24
# TUNIT24 = 'Dimensionless[see description]' / units for column 24
# TUCD24  = 'stat.correlation'
# TTYPE25 = 'astrometric_n_obs_al' / label for column 25
# TFORM25 = 'J       '           / format for column 25
# TUCD25  = 'meta.number'
# TTYPE26 = 'astrometric_n_obs_ac' / label for column 26
# TFORM26 = 'J       '           / format for column 26
# TUCD26  = 'meta.number'
# TTYPE27 = 'astrometric_n_good_obs_al' / label for column 27
# TFORM27 = 'J       '           / format for column 27
# TUCD27  = 'meta.number'
# TTYPE28 = 'astrometric_n_good_obs_ac' / label for column 28
# TFORM28 = 'J       '           / format for column 28
# TUCD28  = 'meta.number'
# TTYPE29 = 'astrometric_n_bad_obs_al' / label for column 29
# TFORM29 = 'J       '           / format for column 29
# TUCD29  = 'meta.number'
# TTYPE30 = 'astrometric_n_bad_obs_ac' / label for column 30
# TFORM30 = 'J       '           / format for column 30
# TUCD30  = 'meta.number'
# TTYPE31 = 'astrometric_delta_q' / label for column 31
# TFORM31 = 'E       '           / format for column 31
# TUCD31  = 'stat.value'
# TTYPE32 = 'astrometric_excess_noise' / label for column 32
# TFORM32 = 'D       '           / format for column 32
# TUNIT32 = 'Angle[mas]'         / units for column 32
# TUCD32  = 'stat.value'
# TTYPE33 = 'astrometric_excess_noise_sig' / label for column 33
# TFORM33 = 'D       '           / format for column 33
# TUCD33  = 'stat.value'
# TTYPE34 = 'astrometric_primary_flag' / label for column 34
# TFORM34 = 'L       '           / format for column 34
# TUCD34  = 'meta.code'
# TTYPE35 = 'astrometric_relegation_factor' / label for column 35
# TFORM35 = 'E       '           / format for column 35
# TUCD35  = 'arith.factor'
# TTYPE36 = 'astrometric_weight_al' / label for column 36
# TFORM36 = 'E       '           / format for column 36
# TUNIT36 = 'Angle[mas^-2]'      / units for column 36
# TUCD36  = 'stat.weight;stat.mean'
# TTYPE37 = 'astrometric_weight_ac' / label for column 37
# TFORM37 = 'E       '           / format for column 37
# TUNIT37 = 'Angle[mas^-2]'      / units for column 37
# TUCD37  = 'stat.weight;stat.mean'
# TTYPE38 = 'astrometric_priors_used' / label for column 38
# TFORM38 = 'J       '           / format for column 38
# TTYPE39 = 'matched_observations' / label for column 39
# TFORM39 = 'I       '           / format for column 39
# TUCD39  = 'meta.number'
# TTYPE40 = 'duplicated_source'  / label for column 40
# TFORM40 = 'L       '           / format for column 40
# TTYPE41 = 'scan_direction_strength_k1' / label for column 41
# TFORM41 = 'E       '           / format for column 41
# TTYPE42 = 'scan_direction_strength_k2' / label for column 42
# TFORM42 = 'E       '           / format for column 42
# TTYPE43 = 'scan_direction_strength_k3' / label for column 43
# TFORM43 = 'E       '           / format for column 43
# TTYPE44 = 'scan_direction_strength_k4' / label for column 44
# TFORM44 = 'E       '           / format for column 44
# TTYPE45 = 'scan_direction_mean_k1' / label for column 45
# TFORM45 = 'E       '           / format for column 45
# TUNIT45 = 'Angle[deg]'         / units for column 45
# TTYPE46 = 'scan_direction_mean_k2' / label for column 46
# TFORM46 = 'E       '           / format for column 46
# TUNIT46 = 'Angle[deg]'         / units for column 46
# TTYPE47 = 'scan_direction_mean_k3' / label for column 47
# TFORM47 = 'E       '           / format for column 47
# TUNIT47 = 'Angle[deg]'         / units for column 47
# TTYPE48 = 'scan_direction_mean_k4' / label for column 48
# TFORM48 = 'E       '           / format for column 48
# TUNIT48 = 'Angle[deg]'         / units for column 48
# TTYPE49 = 'phot_g_n_obs'       / label for column 49
# TFORM49 = 'J       '           / format for column 49
# TUCD49  = 'meta.number'
# TTYPE50 = 'phot_g_mean_flux'   / label for column 50
# TFORM50 = 'D       '           / format for column 50
# TUNIT50 = 'Flux[e-/s]'         / units for column 50
# TCOMM50 = 'Mean flux in the G-band.'
# TUCD50  = 'phot.flux;stat.mean;em.opt'
# TTYPE51 = 'phot_g_mean_flux_error' / label for column 51
# TFORM51 = 'D       '           / format for column 51
# TUNIT51 = 'Flux[e-/s]'         / units for column 51
# TCOMM51 = 'Error on the mean flux in the G-band.'
# TUCD51  = 'stat.error;phot.flux;stat.mean;em.opt'
# TTYPE52 = 'phot_g_mean_mag'    / label for column 52
# TFORM52 = 'D       '           / format for column 52
# TUNIT52 = 'Magnitude[mag]'     / units for column 52
# TUCD52  = 'phot.mag;stat.mean;em.opt'
# TTYPE53 = 'phot_variable_flag' / label for column 53
# TFORM53 = '13A     '           / format for column 53
# TUNIT53 = 'Dimensionless[see description]' / units for column 53
# TUCD53  = 'meta.code;src.var'
# TTYPE54 = 'l       '           / label for column 54
# TFORM54 = 'D       '           / format for column 54
# TUNIT54 = 'Angle[deg]'         / units for column 54
# TUCD54  = 'pos.galactic.lon'
# TTYPE55 = 'b       '           / label for column 55
# TFORM55 = 'D       '           / format for column 55
# TUNIT55 = 'Angle[deg]'         / units for column 55
# TUCD55  = 'pos.galactic.lat'
# TTYPE56 = 'ecl_lon '           / label for column 56
# TFORM56 = 'D       '           / format for column 56
# TUNIT56 = 'Angle[deg]'         / units for column 56
# TUCD56  = 'pos.ecliptic.lon'
# TTYPE57 = 'ecl_lat '           / label for column 57
# TFORM57 = 'D       '           / format for column 57
# TUNIT57 = 'Angle[deg]'         / units for column 57
# TUCD57  = 'pos.ecliptic.lat'
# DATE-HDU= '2016-09-09T04:13:44' / Date of HDU creation (UTC)
# STILVERS= '3.1-1   '           / Version of STIL software
# STILCLAS= 'uk.ac.starlink.votable.FitsPlusTableWriter' / Author class in STIL so

# %% [markdown]
# Astropy provides utils to access the columns entity

# %%
hdu[1].columns
# Out:
# ColDefs(
#     name = 'solution_id'; format = 'K'
#     name = 'source_id'; format = 'K'
#     name = 'random_index'; format = 'K'
#     name = 'ref_epoch'; format = 'D'; unit = 'Time[Julian Years]'
#     name = 'ra'; format = 'D'; unit = 'Angle[deg]'
#     name = 'ra_error'; format = 'D'; unit = 'Angle[mas]'
#     name = 'dec'; format = 'D'; unit = 'Angle[deg]'
#     name = 'dec_error'; format = 'D'; unit = 'Angle[mas]'
#     name = 'parallax'; format = 'D'; unit = 'Angle[mas]'
#     name = 'parallax_error'; format = 'D'; unit = 'Angle[mas]'
#     name = 'pmra'; format = 'D'; unit = 'Angular Velocity[mas/year]'
#     name = 'pmra_error'; format = 'D'; unit = 'Angular Velocity[mas/year]'
#     name = 'pmdec'; format = 'D'; unit = 'Angular Velocity[mas/year]'
#     name = 'pmdec_error'; format = 'D'; unit = 'Angular Velocity[mas/year]'
#     name = 'ra_dec_corr'; format = 'E'; unit = 'Dimensionless[see description]'
#     name = 'ra_parallax_corr'; format = 'E'; unit = 'Dimensionless[see description]'
#     name = 'ra_pmra_corr'; format = 'E'; unit = 'Dimensionless[see description]'
#     name = 'ra_pmdec_corr'; format = 'E'; unit = 'Dimensionless[see description]'
#     name = 'dec_parallax_corr'; format = 'E'; unit = 'Dimensionless[see description]'
#     name = 'dec_pmra_corr'; format = 'E'; unit = 'Dimensionless[see description]'
#     name = 'dec_pmdec_corr'; format = 'E'; unit = 'Dimensionless[see description]'
#     name = 'parallax_pmra_corr'; format = 'E'; unit = 'Dimensionless[see description]'
#     name = 'parallax_pmdec_corr'; format = 'E'; unit = 'Dimensionless[see description]'
#     name = 'pmra_pmdec_corr'; format = 'E'; unit = 'Dimensionless[see description]'
#     name = 'astrometric_n_obs_al'; format = 'J'
#     name = 'astrometric_n_obs_ac'; format = 'J'
#     name = 'astrometric_n_good_obs_al'; format = 'J'
#     name = 'astrometric_n_good_obs_ac'; format = 'J'
#     name = 'astrometric_n_bad_obs_al'; format = 'J'
#     name = 'astrometric_n_bad_obs_ac'; format = 'J'
#     name = 'astrometric_delta_q'; format = 'E'
#     name = 'astrometric_excess_noise'; format = 'D'; unit = 'Angle[mas]'
#     name = 'astrometric_excess_noise_sig'; format = 'D'
#     name = 'astrometric_primary_flag'; format = 'L'
#     name = 'astrometric_relegation_factor'; format = 'E'
#     name = 'astrometric_weight_al'; format = 'E'; unit = 'Angle[mas^-2]'
#     name = 'astrometric_weight_ac'; format = 'E'; unit = 'Angle[mas^-2]'
#     name = 'astrometric_priors_used'; format = 'J'
#     name = 'matched_observations'; format = 'I'
#     name = 'duplicated_source'; format = 'L'
#     name = 'scan_direction_strength_k1'; format = 'E'
#     name = 'scan_direction_strength_k2'; format = 'E'
#     name = 'scan_direction_strength_k3'; format = 'E'
#     name = 'scan_direction_strength_k4'; format = 'E'
#     name = 'scan_direction_mean_k1'; format = 'E'; unit = 'Angle[deg]'
#     name = 'scan_direction_mean_k2'; format = 'E'; unit = 'Angle[deg]'
#     name = 'scan_direction_mean_k3'; format = 'E'; unit = 'Angle[deg]'
#     name = 'scan_direction_mean_k4'; format = 'E'; unit = 'Angle[deg]'
#     name = 'phot_g_n_obs'; format = 'J'
#     name = 'phot_g_mean_flux'; format = 'D'; unit = 'Flux[e-/s]'
#     name = 'phot_g_mean_flux_error'; format = 'D'; unit = 'Flux[e-/s]'
#     name = 'phot_g_mean_mag'; format = 'D'; unit = 'Magnitude[mag]'
#     name = 'phot_variable_flag'; format = '13A'; unit = 'Dimensionless[see description]'
#     name = 'l'; format = 'D'; unit = 'Angle[deg]'
#     name = 'b'; format = 'D'; unit = 'Angle[deg]'
#     name = 'ecl_lon'; format = 'D'; unit = 'Angle[deg]'
#     name = 'ecl_lat'; format = 'D'; unit = 'Angle[deg]'
# )

# %%
hdu[1].columns['parallax']
# Out:
# name = 'parallax'; format = 'D'; unit = 'Angle[mas]'

# %% [markdown]
# whereas the data are accessible with

# %%
hdu[1].data['parallax']
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %% [markdown]
# let's see what we can do with data...

# %%
masknans =np.isnan(hdu[1].data['parallax'])
gaia_parallaxes = hdu[1].data['parallax'][~masknans]
min_para= gaia_parallaxes.min() 
max_para= gaia_parallaxes.max() 
pl.figure(figsize=(15,12))
pl.subplot(221)
_=pl.hist(gaia_parallaxes, bins= np.linspace((min_para), (max_para), 50 ), density=True) 

pl.xlim(0,20)
pl.title( hdu[1].columns['parallax'].name ,  fontsize=15)
pl.xlabel(f"{hdu[1].columns['parallax'].unit}", fontsize=12)
pl.subplot(224)
pl.title( hdu[1].columns['ra'].name ,  fontsize=15)
pl.xlabel(f"{hdu[1].columns['ra'].unit}", fontsize=12)
_=pl.hist(hdu[1].data['ra'][~masknans], bins=  30, density=True ) 
pl.subplot(223)
pl.title( hdu[1].columns['dec'].name ,  fontsize=15)
pl.xlabel(f"{hdu[1].columns['dec'].unit}", fontsize=12)
_=pl.hist(hdu[1].data['dec'][~masknans], bins=  30, density=True ) 
pl.subplot(222)
pl.title( hdu[1].columns['phot_g_mean_mag'].name ,  fontsize=15)
pl.xlabel(f"{hdu[1].columns['phot_g_mean_mag'].unit}", fontsize=12)
_=pl.hist(hdu[1].data['phot_g_mean_mag'][~masknans], bins=  30, density=True )

# %%
ra_fits=hdu[1].data['ra'][~masknans].copy()
dec_fits=hdu[1].data['dec'][~masknans].copy()
hdu.close()

# %% [markdown]
# always remember to close the HDU, otherwise the file remains open.
#
#
# ## reading astropy table
# Another format catalogs can be in is `.csv` or `.dat`, in general txt files. Astropy provides a way to read'em and easily access as they were `.fits`.  This is thanks to the [astropy.ascii.table](https://docs.astropy.org/en/stable/table/index.html#module-astropy.table)
#
# ### Gaia Radial Velocity Spectrometer
#
#
# We download the spectra obtained for several sources acquired with the RVS.
# https://gea.esac.esa.int/archive/documentation/GDR3/Gaia_archive/chap_datamodel/sec_dm_spectroscopic_tables/ssec_dm_rvs_mean_spectrum.html

# %%
try :
    table = ascii.read('RvsMeanSpectrum_000000-003111.csv.gz' ,format='ecsv' )
except FileNotFoundError:
    file= wget.download("http://cdn.gea.esac.esa.int/Gaia/gdr3/Spectroscopy/rvs_mean_spectrum/RvsMeanSpectrum_000000-003111.csv.gz")
    table = ascii.read(file ,format='ecsv' )

# %% [markdown]
# tables are as easy to handle as the fits files,

# %%
table.colnames, table.columns
# Out:
# (['source_id',
#   'solution_id',
#   'ra',
#   'dec',
#   'flux',
#   'flux_error',
#   'combined_transits',
#   'combined_ccds',
#   'deblended_ccds'],
#  <TableColumns names=('source_id','solution_id','ra','dec','flux','flux_error','combined_transits','combined_ccds','deblended_ccds')>)

# %% [markdown]
# the nicest feature is to print a table

# %%
table
# Out:
# <Table length=531>
#     source_id         solution_id     ... combined_ccds deblended_ccds
#                                       ...
#       int64              int64        ...     int16         int16
# ----------------- ------------------- ... ------------- --------------
#     3332894779520 5950420259779346465 ...            30              9
#     9281425163264 5950420259779346465 ...            24              3
#    12545600306304 5950420259779346465 ...            27              2
#    15741055975040 5950420259779346465 ...            33             13
#    17149805245440 5950420259779346465 ...            31             10
#    25980257976960 5950420259779346465 ...            27              2
#    30343944744320 5950420259779346465 ...            34             13
#    45664092292480 5950420259779346465 ...            34             13
#    64325726008320 5950420259779346465 ...            29              9
#               ...                 ... ...           ...            ...
# 26793831354293376 5950420259779346465 ...            45              0
# 26996137198372352 5950420259779346465 ...            42              3
# 27029401720513280 5950420259779346465 ...            37              4
# 27029706662482304 5950420259779346465 ...            38              3
# 27091176234426624 5950420259779346465 ...            26              1
# 27127219599979008 5950420259779346465 ...            32              0
# 27193091514143104 5950420259779346465 ...            30              4
# 27297648197948032 5950420259779346465 ...            20              3
# 27354371830434176 5950420259779346465 ...            27              6
# 27360698317776640 5950420259779346465 ...            26              3

# %%
nrows=table.as_array().shape[0] 
print(table['flux'][0].size) 
rvs_bins  = np.linspace(846,870, table['flux'][0].size )
# Out:
# 2401

# %%
pl.figure(figsize=(15,12))

for i in range(nrows ):  
    pl.subplot(2,4,i+1 )
    #spectrum =   np.float_(table['flux'][i][1:-1].split(',' )  ) 
    spectrum=table['flux'][i]
    pl.title(f"{table['ra'][i]:.2f},{ table['dec'][i]:.2f}")
    pl.plot(rvs_bins,  spectrum ,   )
    if i==7: break

# %%
ra_table= table['ra'] 
dec_table= table['dec'] 

coords_parallax = SkyCoord(ra=ra_fits *u.degree, dec=dec_fits*u.degree)
coords_spectrum  = SkyCoord(ra=ra_table, dec=dec_table)
#

# %% [markdown]
# ###  matching  two catalogs
#
# we match  sources in both catalogs  at about  the same position, so that the match results into sources whose we know parallax and spectrum.
# astropy has a routine that does this

# %%
from astropy.coordinates import match_coordinates_sky
match_coordinates_sky?

# %%
idx, d2d, _ = match_coordinates_sky(coords_parallax , coords_spectrum )

# %%
matchmask = d2d< .1*u.arcsec

# %%
print(f"we matched {coords_parallax[matchmask].size} stars! ")
# Out:
# we matched 57 stars!

# %%
table[idx[matchmask]]
# Out:
# <Table length=57>
#     source_id         solution_id     ... combined_ccds deblended_ccds
#                                       ...
#       int64              int64        ...     int16         int16
# ----------------- ------------------- ... ------------- --------------
#     9281425163264 5950420259779346465 ...            24              3
#    15741055975040 5950420259779346465 ...            33             13
#    86105504493056 5950420259779346465 ...            25              7
#   111600430360448 5950420259779346465 ...            38              5
#   120190364960512 5950420259779346465 ...            30              8
#   139363098967552 5950420259779346465 ...            31              4
#   142730353190144 5950420259779346465 ...            39              3
#   148953761446272 5950420259779346465 ...            29             12
#   189871914442624 5950420259779346465 ...            35              2
#               ...                 ... ...           ...            ...
# 10969178970960000 5950420259779346465 ...            30              1
# 11086169584441600 5950420259779346465 ...            27             15
# 11106785427751936 5950420259779346465 ...            26              5
# 12422321026174720 5950420259779346465 ...            25              3
# 12452557595925120 5950420259779346465 ...            25              4
# 12505536016682112 5950420259779346465 ...            21             16
# 12626035619139456 5950420259779346465 ...            31              9
# 12768770268082560 5950420259779346465 ...            48             10
# 13471804874760192 5950420259779346465 ...            45              0
# 14724900237438464 5950420259779346465 ...            30              2

# %% [markdown]
# ### write a table and save it
#
# let's save into disk a new table encoding only the matched sources, we want to include parallax too into this table.

# %%
tab_match= table[idx[matchmask]]

tab_match.add_column(gaia_parallaxes[matchmask] , name='parallax') 

ascii.write(table = tab_match ,names= tab_match.colnames,fast_writer=False,  output=  f'matched_gaiadata.dat', overwrite=True )

# %% [markdown]
# ##  Cosmology
#
# Another useful feature of Astropy is related to [cosmological calculations](https://docs.astropy.org/en/stable/cosmology/index.html).
# The `astropy.cosmology` sub-package contains classes for representing cosmologies and utility functions for calculating commonly used quantities that depend on a cosmological model. This includes distances, ages, and lookback times corresponding to a measured redshift or the transverse separation corresponding to a measured angular separation.
#
# astropy.cosmology.units extends the astropy.units sub-package, adding and collecting cosmological units and equivalencies, like  for keeping track of (dimensionless) factors of the Hubble constant.

# %%
from astropy.cosmology import Planck18 as cosmo,z_at_value
from astropy.cosmology import FlatLambdaCDM  
cosmo2= FlatLambdaCDM(Ob0=0,Om0=1, H0=70)

# %%
z= np.logspace(-3, 2, 100)
a=  cosmo.scale_factor(z)

# %%
print(cosmo2.age(0),cosmo.age(0))
# Out:
# 9.312306873150373 Gyr 13.786885302009708 Gyr

# %%
pl.figure(figsize=(15,12))
pl.subplot(221)
pl.loglog(z, cosmo.age(z) , label='Age' ) 
pl.loglog(z, cosmo.lookback_time(z)  , label='Lookback time') 
pl.legend() 
pl.xlabel('redshift',fontsize=13)
pl.ylabel(cosmo.age(z).unit,fontsize=13)

pl.subplot(222)
pl.loglog(z, cosmo.comoving_distance(z) , label='Comoving distance' ) 
pl.loglog(z, cosmo.luminosity_distance(z)  , label='Luminosity distance') 
pl.loglog(z, cosmo.angular_diameter_distance(z)  , label='Angular diameter distance') 
pl.loglog(z, cosmo.lookback_distance(z) , label=r'Lookback distance' ) 
pl.xlabel('redshift',fontsize=13)
pl.ylabel(cosmo.comoving_distance(z).unit,fontsize=13)

pl.legend(fontsize=13) 
pl.subplot(224)
pl.loglog(z, cosmo.Ode(z) , label=r'$\Omega_{\Lambda}$' ) 
pl.loglog(z, cosmo.Ogamma(z) , label=r'$\Omega_{r}$' ) 
pl.loglog(z, cosmo.Om(z)  , label=r'$\Omega_{m}$') 
pl.loglog(z, cosmo.Ob(z)  , label=r'$\Omega_{b}$') 
pl.legend(fontsize=13) 
pl.xlabel('redshift',fontsize=13)
# Out:
# Text(0.5, 0, 'redshift')

# %% [markdown]
# if you know a cosmological quantity and you want to know the redshift which it corresponds to, you can use `z_at_value()`.

# %%
print(f"Redshift of M31 :{z_at_value(cosmo.luminosity_distance, 765*u.kpc) }" ) 
print(f"Redshift of an object in the Hubble flow :{z_at_value(cosmo.comoving_distance, cosmo.hubble_distance,) }" )
# Out:
# Redshift of M31 :0.0001726295870857113 redshift
# Redshift of an object in the Hubble flow :1.4755193476506416 redshift
